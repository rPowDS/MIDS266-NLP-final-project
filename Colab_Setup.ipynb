# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Notebook: Project Initialization
#
# This notebook is responsible for initializing the core directory structure within Google Drive for the entire project. It ensures that all necessary subdirectories like `data`, `models`, `outputs`, `notebooks`, `configs`, `tables`, and `figs` are created. This setup provides consistency across  project stages.
#
#
# Essentially, this notebook lays the groundwork for an organized and efficient project workflow.

# %%
import os

# %%
BASE_DIR = '/content/drive/MyDrive/w266_project_final'

# %%
subdirs = [
    "data",
    "models",
    "outputs",
    "notebooks",
    "configs",
    "tables",
    "figs"
]

# %%
os.makedirs(BASE_DIR, exist_ok=True)
for s in subdirs:
  os.makedirs(os.path.join(BASE_DIR, s), exist_ok=True)

BASE_DIR
# Out:
# '/content/drive/MyDrive/w266_project_final'
